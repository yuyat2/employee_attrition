# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Employe_Attrition.csv')
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# ...

# %%
drop_col = ['Over18', 'EmployeeNumber','EmployeeCount', 'StandardHours']
df_new = df.drop(drop_col, axis=1)

# %%
#counting NaN
df_new.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# ...

# %%
#business travel
#Travel_Frequently > Travel_Rarely > Non_Travel
size_mapping = {'Travel_Frequently':3, 'Travel_Rarely': 2, 'Non-Travel':1}
#transform categorical data into numeric number
df_new['BusinessTravel'] = df_new['BusinessTravel'].map(size_mapping)
df_new.head()
# Out:
#    Age Attrition  BusinessTravel  DailyRate              Department  \
# 0   41       Yes               2       1102                   Sales
# 1   49        No               3        279  Research & Development
# 2   37       Yes               2       1373  Research & Development
# 3   33        No               3       1392  Research & Development
# 4   27        No               2        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender         ...           PerformanceRating  RelationshipSatisfaction  \
# ...

# %%
size_mapping_attrition = {'Yes': 1, 'No': 0}
df_new['Attrition'] = df_new['Attrition'].map(size_mapping_attrition)
df_new.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate              Department  \
# 0   41          1               2       1102                   Sales
# 1   49          0               3        279  Research & Development
# 2   37          1               2       1373  Research & Development
# 3   33          0               3       1392  Research & Development
# 4   27          0               2        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender         ...           PerformanceRating  RelationshipSatisfaction  \
# ...

# %%
df_new = pd.get_dummies(df_new)

# %%
df_new.head()
# Out:
#    Age  Attrition  BusinessTravel  DailyRate  DistanceFromHome  Education  \
# 0   41          1               2       1102                 1          2
# 1   49          0               3        279                 8          1
# 2   37          1               2       1373                 2          2
# 3   33          0               3       1392                 3          4
# 4   27          0               2        591                 2          1
#
#    EnvironmentSatisfaction  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2          94               3         2
# 1                        3          61               2         2
# 2                        4          92               2         1
# 3                        4          56               3         1
# 4                        1          40               3         1
#
#        ...       JobRole_Manufacturing Director  JobRole_Research Director  \
# ...

# %%
print(df_new.columns)
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'DistanceFromHome',
#        'Education', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate',
#        'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'Department_Human Resources', 'Department_Research & Development',
#        'Department_Sales', 'EducationField_Human Resources',
#        'EducationField_Life Sciences', 'EducationField_Marketing',
#        'EducationField_Medical', 'EducationField_Other',
#        'EducationField_Technical Degree', 'Gender_Female', 'Gender_Male',
#        'JobRole_Healthcare Representative', 'JobRole_Human Resources',
# ...

# %%
df_new = df_new.loc[:, ['Attrition', 'Age', 'BusinessTravel', 'DailyRate', 'DistanceFromHome',
       'Education', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement',
       'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate',
       'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
       'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
       'Department_Human Resources', 'Department_Research & Development',
       'Department_Sales', 'EducationField_Human Resources',
       'EducationField_Life Sciences', 'EducationField_Marketing',
       'EducationField_Medical', 'EducationField_Other',
       'EducationField_Technical Degree', 'Gender_Female', 'Gender_Male',
       'JobRole_Healthcare Representative', 'JobRole_Human Resources',
       'JobRole_Laboratory Technician', 'JobRole_Manager',
       'JobRole_Manufacturing Director', 'JobRole_Research Director',
       'JobRole_Research Scientist', 'JobRole_Sales Executive',
       'JobRole_Sales Representative', 'MaritalStatus_Divorced',
       'MaritalStatus_Married', 'MaritalStatus_Single', 'OverTime_No',
       'OverTime_Yes']]

# %%
from sklearn.cross_validation import train_test_split
X, y = df_new.iloc[:, 1:].values, df_new.iloc[:, 0].values
#separateing into training data and test data
#set test data as 30%
X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size = 0.3, random_state = 1212, stratify = y)
# Out:
# /Users/yuya/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#X_train_std = sc.fit_transform(X_train)
#X_train_std = sc.fit(X_train)
#X_test_std = sc.fit_transform(X_test)
#X_combined_std = np.vstack((X_train_std, X_test_std))
#y_combined = np.hstack((y_train, y_test))
#X = pd.DataFrame({})

# %%
#X_scaled = sc.fit(X_combined_std)

# %%
#Logistic regression用にtraining data setとtest data setをそれぞれdata
#frame化する
#df_new_train, df_new_test = train_test_split(df_new, test_size=0.3, 
                                             #random_state = 1212, stratify = y)

logreg_cols = ['Age', 'BusinessTravel', 'DailyRate', 'DistanceFromHome',
       'Education', 'EnvironmentSatisfaction', 'HourlyRate', 'JobInvolvement',
       'JobLevel', 'JobSatisfaction', 'MonthlyIncome', 'MonthlyRate',
       'NumCompaniesWorked', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
       'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
       'Department_Human Resources', 'Department_Research & Development',
       'Department_Sales', 'EducationField_Human Resources',
       'EducationField_Life Sciences', 'EducationField_Marketing',
       'EducationField_Medical', 'EducationField_Other',
       'EducationField_Technical Degree', 'Gender_Female', 'Gender_Male',
       'JobRole_Healthcare Representative', 'JobRole_Human Resources',
       'JobRole_Laboratory Technician', 'JobRole_Manager',
       'JobRole_Manufacturing Director', 'JobRole_Research Director',
       'JobRole_Research Scientist', 'JobRole_Sales Executive',
       'JobRole_Sales Representative', 'MaritalStatus_Divorced',
       'MaritalStatus_Married', 'MaritalStatus_Single', 'OverTime_No',
       'OverTime_Yes']

#X_logreg = df_new_train[logreg_cols]
#y_logreg = df_new_train['Attrition']

# over-sampling using SMOTE
from imblearn.over_sampling import SMOTE

os = SMOTE(random_state = 1212)
#columns_smote = X_train['logreg_cols']

os_data_X, os_data_y = os.fit_sample(X_train, y_train)
os_data_X = pd.DataFrame(data = os_data_X, columns = logreg_cols)
os_data_y = pd.DataFrame(data = os_data_y, columns = ['Attrition'])

#check the number of data
print("length of oversampled data is" , len(os_data_X))

print("number of attrition_yes in oversampled data is", len(os_data_y[os_data_y['Attrition'] == 1]))
print("number of attrition_no in oversampled data is", len(os_data_y[os_data_y['Attrition'] == 0]))

print("proportion of attrition_yes in oversampled data is", len(os_data_y[os_data_y['Attrition'] == 1])/ 
     len(os_data_X))
print("proportion of attrition_no in oversampled data is", len(os_data_y[os_data_y['Attrition'] == 0])/ 
     len(os_data_X))

#model = LogisticRegression()
#rfe = RFE(model, 25)
#rfe = rfe.fit(X_logreg, y_logreg)
#print('Selected features: %s' % list(X_logreg.columns[rfe.support_]))
# Out:
# length of oversampled data is 1726
# number of attrition_yes in oversampled data is 863
# number of attrition_no in oversampled data is 863
# proportion of attrition_yes in oversampled data is 0.5
# proportion of attrition_no in oversampled data is 0.5

# %%
#tuning parameter for Logstic regression
import matplotlib.pyplot as plt
from sklearn.model_selection import learning_curve
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
pipe_lr = make_pipeline(StandardScaler(),
                       LogisticRegression(penalty = 'l2', random_state = 1212))
#learning_curveでcrossvalidationによる正解率を算出
train_sizes, train_scores, test_scores = learning_curve(estimator = pipe_lr,
                                                       X = X_train,
                                                       y = y_train,
                                                       train_sizes = np.linspace(0.1, 1.0, 10),
                                                       cv = 10,
                                                       n_jobs = 1)
train_mean = np.mean(train_scores, axis = 1)
train_std = np.std(train_scores, axis = 1)
test_mean = np.mean(test_scores, axis = 1)
test_std = np.std(test_scores, axis = 1)

plt.plot(train_sizes, train_mean,
        color = 'blue', marker = 'o',
        markersize = 5,
        label = 'training accuracy')
plt.fill_between(train_sizes, 
        train_mean + train_std,
        train_mean - train_std,
        alpha = 0.15, color = 'blue')

plt.plot(train_sizes, test_mean,
        color = 'red', linestyle = '--',
        marker = 's', markersize = 5,
        label = 'validation accuracy')
plt.fill_between(train_sizes, 
        test_mean + test_std,
        test_mean - test_std,
        alpha = 0.15, color = 'red')
plt.grid()
plt.xlabel('Number of training samples')
plt.ylabel('Accuracy score')
plt.legend(loc = 'lower right')
plt.ylim([0.7, 1.0])
plt.tight_layout()
plt.savefig('Learning curve', dpi=300)
#plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-3764961e0db8> in <module>
#       5 from sklearn.preprocessing import StandardScaler
#       6 pipe_lr = make_pipeline(StandardScaler(),
# ----> 7                        LogisticRegression(penalty = 'l2', random_state = 1212))
#       8 #learning_curveでcrossvalidationによる正解率を算出
#       9 train_sizes, train_scores, test_scores = learning_curve(estimator = pipe_lr,
#
# NameError: name 'LogisticRegression' is not defined

# %%
#validation curveの作成
from sklearn.model_selection import validation_curve
param_range = [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]

lg_train_scores, lg_test_scores = validation_curve(estimator = pipe_lr,
                                                       X = X_train,
                                                       y = y_train,
                                                       param_name = 'logisticregression__C',
                                                   param_range = param_range,
                                                       cv = 10)
lg_train_mean = np.mean(lg_train_scores, axis = 1)
lg_train_std = np.std(lg_train_scores, axis = 1)
lg_test_mean = np.mean(lg_test_scores, axis = 1)
lg_test_std = np.std(lg_test_scores, axis = 1)

plt.plot(param_range, lg_train_mean,
        color = 'blue', marker = 'o',
        markersize = 5,
        label = 'training accuracy')
plt.fill_between(param_range, 
        lg_train_mean + lg_train_std,
        lg_train_mean - lg_train_std,
        alpha = 0.15, color = 'blue')

plt.plot(param_range, lg_test_mean,
        color = 'red', linestyle = '--',
        marker = 's', markersize = 5,
        label = 'validation accuracy')
plt.fill_between(param_range, 
        lg_test_mean + lg_test_std,
        lg_test_mean - lg_test_std,
        alpha = 0.15, color = 'red')
plt.grid()
plt.xscale('log')
plt.legend(loc = 'lower right')
plt.xlabel('Parameter C')
plt.ylabel('Accuracy score')
plt.ylim([0.7, 1.0])
plt.tight_layout()
plt.savefig('Validation curve', dpi=300)
#plt.show()

# %%
#以上より0.1がベストかな
#Recursive Feature Elimination(RFE)
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression(C= 0.1, random_state = 1212)

#select 26 variables
rfe = RFE(logreg, 26)
rfe = rfe.fit(os_data_X, os_data_y.values.ravel())
print(rfe.support_)
print(rfe.ranking_)
# Out:
# [False  True False False False  True False  True  True  True False False
#  False False  True False False False  True False False False  True  True
#   True False  True  True  True False False False  True False  True False
#   True  True  True  True  True False  True  True  True False  True  True
#   True]
# [16  1 23 14 15  1 21  1  1  1 22 24  5 13  1 12  4 17  1  3 11  8  1  1
#   1  7  1  1  1  2 10  6  1 20  1 19  1  1  1  1  1 18  1  1  1  9  1  1
#   1]

# %%
print(df_new.columns[16])
print(df_new.columns[1])
print(df_new.columns[23])
print(df_new.columns[14])
print(df_new.columns[15])
print(df_new.columns[21])
print(df_new.columns[22])
print(df_new.columns[24])
print(df_new.columns[5])
print(df_new.columns[13])
print(df_new.columns[12])
print(df_new.columns[4])
print(df_new.columns[17])
print(df_new.columns[3])
print(df_new.columns[11])
print(df_new.columns[8])
print(df_new.columns[7])
print(df_new.columns[2])
print(df_new.columns[10])
print(df_new.columns[6])
print(df_new.columns[20])
print(df_new.columns[19])
print(df_new.columns[18])
print(df_new.columns[9])
# Out:
# RelationshipSatisfaction
# Age
# YearsSinceLastPromotion
# PercentSalaryHike
# PerformanceRating
# YearsAtCompany
# YearsInCurrentRole
# YearsWithCurrManager
# Education
# NumCompaniesWorked
# MonthlyRate
# DistanceFromHome
# StockOptionLevel
# DailyRate
# MonthlyIncome
# JobInvolvement
# HourlyRate
# BusinessTravel
# JobSatisfaction
# EnvironmentSatisfaction
# WorkLifeBalance
# TrainingTimesLastYear
# TotalWorkingYears
# JobLevel

# %%
logreg.fit(os_data_X, os_data_y)
logreg.coef_
# Out:
# /Users/yuya/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([[-3.69628306e-02,  9.70410581e-01, -1.58650688e-05,
#          4.54404571e-02,  9.42868118e-02, -4.52139332e-01,
#          4.86203418e-03, -5.48869030e-01,  8.78971908e-02,
#         -1.68253075e-01, -1.06927750e-04,  1.06007459e-05,
#          1.98401415e-01, -6.37405648e-02,  7.29559379e-01,
#         -8.76780111e-02, -1.61489179e-01, -2.93390739e-02,
#         -1.63169847e-01, -4.67583000e-02,  1.15927016e-01,
#         -1.48301554e-01,  1.52290725e-01, -1.74434868e-01,
#          7.70654711e-02, -1.13777453e-01,  3.86717105e-01,
#          7.38683653e-02, -2.82806157e-01,  1.86682783e-01,
#         -1.58984139e-01, -7.81360259e-02,  6.09380296e-01,
# ...

# %%
c = [-3.69628306e-02,  9.70410581e-01, -1.58650688e-05,
         4.54404571e-02,  9.42868118e-02, -4.52139332e-01,
         4.86203418e-03, -5.48869030e-01,  8.78971908e-02,
        -1.68253075e-01, -1.06927750e-04,  1.06007459e-05,
         1.98401415e-01, -6.37405648e-02,  7.29559379e-01,
        -8.76780111e-02, -1.61489179e-01, -2.93390739e-02,
        -1.63169847e-01, -4.67583000e-02,  1.15927016e-01,
        -1.48301554e-01,  1.52290725e-01, -1.74434868e-01,
         7.70654711e-02, -1.13777453e-01,  3.86717105e-01,
         7.38683653e-02, -2.82806157e-01,  1.86682783e-01,
        -1.58984139e-01, -7.81360259e-02,  6.09380296e-01,
        -9.95742031e-02,  4.49579326e-01, -8.66204736e-02,
         1.52445103e-01,  5.25880782e-01, -1.75730296e-01,
        -2.30625984e-01, -1.54520964e-01, -1.27096101e-01,
         9.77526819e-02,  3.48520375e-01, -3.08918203e-01,
        -1.13472149e-01,  7.72395475e-01, -7.47039194e-01,
         1.09704432e+00]

abs_coef = sorted(c, key=abs, reverse=True)
print(abs_coef)
# Out:
# [1.09704432, 0.970410581, 0.772395475, -0.747039194, 0.729559379, 0.609380296, -0.54886903, 0.525880782, -0.452139332, 0.449579326, 0.386717105, 0.348520375, -0.308918203, -0.282806157, -0.230625984, 0.198401415, 0.186682783, -0.175730296, -0.174434868, -0.168253075, -0.163169847, -0.161489179, -0.158984139, -0.154520964, 0.152445103, 0.152290725, -0.148301554, -0.127096101, 0.115927016, -0.113777453, -0.113472149, -0.0995742031, 0.0977526819, 0.0942868118, 0.0878971908, -0.0876780111, -0.0866204736, -0.0781360259, 0.0770654711, 0.0738683653, -0.0637405648, -0.0467583, 0.0454404571, -0.0369628306, -0.0293390739, 0.00486203418, -0.00010692775, -1.58650688e-05, 1.06007459e-05]

# %%
cols_ref = ['RelationshipSatisfaction', 'Age', 'YearsSinceLastPromotion',
            'PercentSalaryHike','PerformanceRating',
            'YearsAtCompany','YearsInCurrentRole','YearsWithCurrManager',
            'Education','NumCompaniesWorked','MonthlyRate',
            'DistanceFromHome','StockOptionLevel','DailyRate',
            'MonthlyIncome','JobInvolvement','HourlyRate',
            'BusinessTravel','JobSatisfaction','EnvironmentSatisfaction',
            'WorkLifeBalance','TrainingTimesLastYear','TotalWorkingYears',
            'JobLevel']

X = os_data_X[cols_ref]
y = os_data_y['Attrition']

# %%
#logistic regression
import statsmodels.api as sm
logit_model = sm.Logit(y, X)
result = logit_model.fit()
print(result.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.532937
#          Iterations 6
#                              Results: Logit
# ...
# Model:                Logit              Pseudo R-squared:   0.231
# Dependent Variable:   Attrition          AIC:                1887.6983
# Date:                 2019-01-11 19:00   BIC:                2018.5837
# No. Observations:     1726               Log-Likelihood:     -919.85
# Df Model:             23                 LL-Null:            -1196.4
# Df Residuals:         1702               LLR p-value:        3.0692e-102
# Converged:            1.0000             Scale:              1.0000
# No. Iterations:       6.0000
# ------------------------------------------------------------------------
#                           Coef.  Std.Err.    z    P>|z|   [0.025  0.975]
# ------------------------------------------------------------------------
# RelationshipSatisfaction -0.0740   0.0578 -1.2809 0.2002 -0.1873  0.0392
# ...

# %%
#delete variables whose p-value is larger than 0.05
cols_p = ['Age','YearsSinceLastPromotion','PercentSalaryHike','PerformanceRating',
          'YearsAtCompany','YearsInCurrentRole','YearsWithCurrManager',
          'NumCompaniesWorked','DistanceFromHome','StockOptionLevel',
          'MonthlyIncome','JobInvolvement','BusinessTravel',
          'JobSatisfaction', 'EnvironmentSatisfaction', 'TrainingTimesLastYear']

# %%
X_p = os_data_X[cols_p]
y_p = os_data_y['Attrition']

df_logit = np.concatenate((y))

logit_model_p = sm.Logit(y_p, X_p)
result_p = logit_model_p.fit()
#print(result_p.summary2())

import codecs
summary2 = result_p.summary2()
print(summary2, file = codecs.open('summary_of_logistic_regression.txt', 
                                  'w', 'utf-8'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-35c09441b185> in <module>
#       2 y_p = os_data_y['Attrition']
#       3
# ----> 4 df_logit = pd.merge(y_p, X_p)
#       5
#       6 logit_model_p = sm.Logit(y_p, X_p)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      59                          right_index=right_index, sort=sort, suffixes=suffixes,
#      60                          copy=copy, indicator=indicator,
# ---> 61                          validate=validate)
#      62     return op.get_result()
#      63
#
# ...

# %%
np.exp(result_p.params)
# Out:
# Age                        0.958874
# YearsSinceLastPromotion    1.170402
# PercentSalaryHike          0.908639
# PerformanceRating          3.932923
# YearsAtCompany             1.079832
# YearsInCurrentRole         0.862745
# YearsWithCurrManager       0.862831
# NumCompaniesWorked         1.194526
# DistanceFromHome           1.045122
# StockOptionLevel           0.613906
# MonthlyIncome              0.999869
# JobInvolvement             0.584114
# BusinessTravel             2.715852
# JobSatisfaction            0.895959
# EnvironmentSatisfaction    0.680806
# TrainingTimesLastYear      0.833151
# dtype: float64

# %%
p_hat = np.exp(result_p.params)/(1 + np.exp(result_p.params))
p_hat
# Out:
# Age                        0.489503
# YearsSinceLastPromotion    0.539256
# PercentSalaryHike          0.476066
# PerformanceRating          0.797280
# YearsAtCompany             0.519192
# YearsInCurrentRole         0.463158
# YearsWithCurrManager       0.463183
# NumCompaniesWorked         0.544321
# DistanceFromHome           0.511032
# StockOptionLevel           0.380385
# MonthlyIncome              0.499967
# JobInvolvement             0.368732
# BusinessTravel             0.730883
# JobSatisfaction            0.472563
# EnvironmentSatisfaction    0.405047
# TrainingTimesLastYear      0.454491
# dtype: float64

# %%
pd.qcut(df[''], 10)

# %%
#feature selection by logistic regression
#from sklearn.linear_model import LogisticRegression
#from sklearn.feature_selection import RFE
#import numpy as np 
#import pandas as pd
#import matplotlib.pyplot as plt 

#feature ranking
#from sklearn.feature_selection import RFECV
#rfecv = RFECV(estimator = LogisticRegression(), step = 1, cv = 10, scoring = 'accuracy')
#rfecv.fit(X_logreg, y_logreg)

#print("Optimal number of features: %d" % rfecv.n_features_)
#print('Selected features: %s' % list(X_logreg.columns[rfecv.support_]))

#plt.figure(figsize=(15,10))
#plt.xlabel("Number of features selected")
#plt.ylabel("Cross validation score (numberb of correct classifications)")
#plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
#plt.show()


#generate instance of L1 normalization for logistic regression
#clf = LogisticRegression(penalty = 'l1', random_state = 1212)
#clf.fit(X_scaled, y_combined)

# %%
#generate instance of L1 normalization for logistic regression(c = 1.0)
#lr = LogisticRegression(penalty = 'l1', C = 1.0)
#lr.fit(X_train_std, y_train)
#acuracy rate of training data
#print('training accuracy:', lr.score(X_train_std, y_train))
#accuracy rate of test data
#print('test accuracy:', lr.score(X_test_std, y_test))
#ほんのちょっとだけ過学習が起きている
# Out:
# training accuracy: 0.8950437317784257
# test accuracy: 0.891156462585034

# %%
#feature importance by random forest
#random forestは特にデータをいじる必要がない
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
feat_labels = df_new.columns[1:]

forest = RandomForestClassifier(n_estimators = 100, 
                               random_state = 1212)
forest.fit(X_train, y_train)
importances = forest.feature_importances_
#sorting
indices = np.argsort(importances)[::-1]

for f in range(X_train.shape[1]):
    print("%2d) %-*s %f" % (f + 1, 30, 
                            feat_labels[indices[f]], 
                            importances[indices[f]]))

fig = plt.figure(figsize=(15,10),dpi=200)
    
plt.title('Attrition(Feature Importance)')
plt.bar(range(X_train.shape[1]),
       importances[indices],
       align = 'center')
plt.xticks(range(X_train.shape[1]),
          feat_labels[indices], rotation = 90)
plt.xlim([-1, X_train.shape[1]])
plt.tight_layout()
#plt.show()
fig.savefig('figure.png')
# Out:
# /Users/yuya/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
#  1) MonthlyIncome                  0.089023
#  2) Age                            0.061456
#  3) TotalWorkingYears              0.054048
#  4) DistanceFromHome               0.047366
#  5) MonthlyRate                    0.046906
#  6) DailyRate                      0.046192
#  7) HourlyRate                     0.042652
#  8) NumCompaniesWorked             0.036458
#  9) YearsAtCompany                 0.035534
# 10) OverTime_Yes                   0.034557
# 11) OverTime_No                    0.034391
# 12) EnvironmentSatisfaction        0.030526
# 13) PercentSalaryHike              0.028714
# 14) YearsWithCurrManager           0.026840
# 15) JobInvolvement                 0.025717
# ...

# %%
print(df_new.columns.get_loc('Attrition'))
print(df_new.columns.get_loc('MonthlyIncome'))
print(df_new.columns.get_loc('Age'))
print(df_new.columns.get_loc('TotalWorkingYears'))
print(df_new.columns.get_loc('DistanceFromHome'))
print(df_new.columns.get_loc('MonthlyRate'))
print(df_new.columns.get_loc('DailyRate'))
print(df_new.columns.get_loc('HourlyRate'))
print(df_new.columns.get_loc('NumCompaniesWorked'))
print(df_new.columns.get_loc('YearsAtCompany'))
print(df_new.columns.get_loc('OverTime_Yes'))
print(df_new.columns.get_loc('OverTime_No'))
print(df_new.columns.get_loc('EnvironmentSatisfaction'))
print(df_new.columns.get_loc('PercentSalaryHike'))
print(df_new.columns.get_loc('YearsWithCurrManager'))
print(df_new.columns.get_loc('JobInvolvement'))
print(df_new.columns.get_loc('YearsInCurrentRole'))
print(df_new.columns.get_loc('YearsSinceLastPromotion'))
print(df_new.columns.get_loc('TrainingTimesLastYear'))
print(df_new.columns.get_loc('JobSatisfaction'))
print(df_new.columns.get_loc('RelationshipSatisfaction'))
print(df_new.columns.get_loc('WorkLifeBalance'))
print(df_new.columns.get_loc('StockOptionLevel'))
print(df_new.columns.get_loc('JobLevel'))
print(df_new.columns.get_loc('BusinessTravel'))
print(df_new.columns.get_loc('Education'))
print(df_new.columns.get_loc('MaritalStatus_Single'))
# Out:
# 0
# 11
# 1
# 18
# 4
# 12
# 3
# 7
# 13
# 21
# 49
# 48
# 6
# 14
# 24
# 8
# 22
# 23
# 19
# 10
# 16
# 20
# 17
# 9
# 2
# 5
# 47

# %%
#重要度が0.01以上を選択
df_rf = df_new.iloc[:, [0,11,1,18,4,12,3,7,13,21,49,48,6,14,24,8,22,
                        23,19,10,16,20,17,9,2,5,47]]
df_rf.head()
# Out:
#    Attrition  MonthlyIncome  Age  TotalWorkingYears  DistanceFromHome  \
# 0          1           5993   41                  8                 1
# 1          0           5130   49                 10                 8
# 2          1           2090   37                  7                 2
# 3          0           2909   33                  8                 3
# 4          0           3468   27                  6                 2
#
#    MonthlyRate  DailyRate  HourlyRate  NumCompaniesWorked  YearsAtCompany  \
# 0        19479       1102          94                   8               6
# 1        24907        279          61                   1              10
# 2         2396       1373          92                   6               0
# 3        23159       1392          56                   1               8
# 4        16632        591          40                   9               2
#
#            ...           YearsSinceLastPromotion  TrainingTimesLastYear  \
# ...

# %%
#majority vote classifierの実装
from sklearn.base import BaseEstimator
from sklearn.base import ClassifierMixin
from sklearn.preprocessing import LabelEncoder
from sklearn.externals import six
from sklearn.base import clone
from sklearn.pipeline import _name_estimators
import numpy as np
import operator


class MajorityVoteClassifier(BaseEstimator, 
                             ClassifierMixin):
    def __init__(self, classifiers, vote='classlabel', weights=None):

        self.classifiers = classifiers
        self.named_classifiers = {key: value for key, value
                                  in _name_estimators(classifiers)}
        self.vote = vote
        self.weights = weights

    def fit(self, X, y):
        if self.vote not in ('probability', 'classlabel'):
            raise ValueError("vote must be 'probability' or 'classlabel'"
                             "; got (vote=%r)"
                             % self.vote)

        if self.weights and len(self.weights) != len(self.classifiers):
            raise ValueError('Number of classifiers and weights must be equal'
                             '; got %d weights, %d classifiers'
                             % (len(self.weights), len(self.classifiers)))

        self.lablenc_ = LabelEncoder()
        self.lablenc_.fit(y)
        self.classes_ = self.lablenc_.classes_
        self.classifiers_ = []
        for clf in self.classifiers:
            fitted_clf = clone(clf).fit(X, self.lablenc_.transform(y))
            self.classifiers_.append(fitted_clf)
        return self

    def predict(self, X):
        if self.vote == 'probability':
            maj_vote = np.argmax(self.predict_proba(X), axis=1)
        else:  
            predictions = np.asarray([clf.predict(X)
                                      for clf in self.classifiers_]).T

            maj_vote = np.apply_along_axis(
                                      lambda x:
                                      np.argmax(np.bincount(x,
                                                weights=self.weights)),
                                      axis=1,
                                      arr=predictions)
        maj_vote = self.lablenc_.inverse_transform(maj_vote)
        return maj_vote

    def predict_proba(self, X):
        probas = np.asarray([clf.predict_proba(X)
                             for clf in self.classifiers_])
        avg_proba = np.average(probas, axis=0, weights=self.weights)
        return avg_proba

    def get_params(self, deep=True):
        if not deep:
            return super(MajorityVoteClassifier, self).get_params(deep=False)
        else:
            out = self.named_classifiers.copy()
            for name, step in six.iteritems(self.named_classifiers):
                for key, value in six.iteritems(step.get_params(deep=True)):
                    out['%s__%s' % (name, key)] = value
            return out

# %%
#Logistic Regression, Decision Tree Classifier, K Neighbors Classifier等の比較
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier 
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score

clf1 = LogisticRegression(C=0.1,
                          random_state=1212)

clf2 = DecisionTreeClassifier(max_depth=4,
                              criterion='gini',
                              random_state=1212)

#clf3 = KNeighborsClassifier(n_neighbors=1,
                            #p=2,
                            #metric='minkowski')

pipe1 = Pipeline([['sc', StandardScaler()],
                  ['clf', clf1]])

#pipe3 = Pipeline([['sc', StandardScaler()],
                  #['clf', clf3]])


clf_labels = ['Logistic regression','Decision tree']

print('10-fold cross validation:\n')
for clf, label in zip([pipe1, clf2], clf_labels):
    scores = cross_val_score(estimator=clf,
                             X=X_train,
                             y=y_train,
                             cv=10,
                             scoring='roc_auc')
    print("ROC AUC: %0.2f (+/- %0.2f) [%s]"
          % (scores.mean(), scores.std(), label))
# Out:
# 10-fold cross validation:
#
# ROC AUC: 0.82 (+/- 0.04) [Logistic regression]
# /Users/yuya/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/yuya/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/yuya/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/yuya/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# ...

# %%
# Majority Rule (hard) Voting
#Logistic, Decision Tree, KNNで良いモデルに多数決をとる
#mv_clf = MajorityVoteClassifier(classifiers=[pipe1, clf2])

#clf_labels += ['Majority voting']
all_clf = [pipe1, clf2]

for clf, label in zip(all_clf):
    scores = cross_val_score(estimator=clf,
                             X=X_train,
                             y=y_train,
                             cv=10,
                             scoring='roc_auc')
    print("ROC AUC: %0.2f (+/- %0.2f) [%s]"
          % (scores.mean(), scores.std(), label))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-66-3a09978c44ea> in <module>
#       6 all_clf = [pipe1, clf2]
#       7
# ----> 8 for clf, label in zip(all_clf):
#       9     scores = cross_val_score(estimator=clf,
#      10                              X=X_train,
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %%
#ROCのvisualization
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve
from sklearn.metrics import auc

colors = ['red', 'blue', 'green']
linestyles = [':', '--', '-.']
for clf, label, clr, ls \
        in zip(all_clf,
               clf_labels, colors, linestyles):
    y_pred = clf.fit(X_train,
                     y_train).predict_proba(X_test)[:, 1]
    fpr, tpr, thresholds = roc_curve(y_true=y_test,
                                     y_score=y_pred)
    roc_auc = auc(x=fpr, y=tpr)
    plt.plot(fpr, tpr,
             color=clr,
             linestyle=ls,
             label='%s (auc = %0.2f)' % (label, roc_auc))

plt.legend(loc='lower right')
plt.plot([0, 1], [0, 1],
         linestyle='--',
         color='gray',
         linewidth=2)

plt.xlim([-0.1, 1.1])
plt.ylim([-0.1, 1.1])
plt.grid(alpha=0.5)
plt.xlabel('False positive rate (FPR)')
plt.ylabel('True positive rate (TPR)')

plt.savefig('ROC_curve', dpi=300)
#plt.show()
# Out:
# /Users/yuya/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/yuya/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/yuya/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
#hyper parameter tuning & finding the best number of tree depth
from sklearn.model_selection import GridSearchCV

params = {'decisiontreeclassifier__max_depth': [3,4,5],
          'pipeline-1__clf__C': [0.01, 0.1,10.0]}

grid = GridSearchCV(estimator=mv_clf,
                    param_grid=params,
                    cv=10,
                    scoring='roc_auc')
grid.fit(X_train, y_train)

for r, _ in enumerate(grid.cv_results_['mean_test_score']):
    print("%0.3f +/- %0.2f %r"
          % (grid.cv_results_['mean_test_score'][r], 
             grid.cv_results_['std_test_score'][r] / 2.0, 
             grid.cv_results_['params'][r]))
# Out:
# /Users/yuya/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/yuya/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/yuya/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# /Users/yuya/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# ...

# %%
print('Best parameters: %s' % grid.best_params_)
print('Accuracy: %.2f' % grid.best_score_)
# Out:
# Best parameters: {'decisiontreeclassifier__max_depth': 4, 'pipeline-1__clf__C': 0.1}
# Accuracy: 0.78

# %%
from sklearn.model_selection import train_test_split
X_rf, y_rf = df_rf.iloc[:, 1:].values, df_rf.iloc[:, 0].values

X_train_rf, X_test_rf, y_train_rf, y_test_rf =\
    train_test_split(X_rf,y_rf,
                    test_size = 0.3,
                    random_state = 1212,
                    stratify = y_rf)

# %%
print(df_rf.columns)
# Out:
# Index(['Attrition', 'MonthlyIncome', 'Age', 'TotalWorkingYears',
#        'DistanceFromHome', 'MonthlyRate', 'DailyRate', 'HourlyRate',
#        'NumCompaniesWorked', 'YearsAtCompany', 'OverTime_Yes', 'OverTime_No',
#        'EnvironmentSatisfaction', 'PercentSalaryHike', 'YearsWithCurrManager',
#        'JobInvolvement', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'TrainingTimesLastYear', 'JobSatisfaction', 'RelationshipSatisfaction',
#        'WorkLifeBalance', 'StockOptionLevel', 'JobLevel', 'BusinessTravel',
#        'Education', 'MaritalStatus_Single'],
#       dtype='object')

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(C=0.1, random_state=1212)
lr.fit(X_train_std, y_train_rf)
lr.score(X_train_std, y_train_rf)

#plot_decision_regions(X_combined_std, y_combined,
                      #classifier=lr, test_idx=range(105, 150))
#plt.xlabel('features')
#plt.ylabel('Attrition')
#plt.legend(loc='upper left')
#plt.tight_layout()
#plt.savefig('Logistic_regression.png', dpi=300)
#plt.show()
# Out:
# 0.880466472303207

# %%
#coeff_df = DataFrame([X_train_std.columns, lr.coef_[0]]).T
#coeff_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-3f325ca5233a> in <module>()
# ----> 1 coeff_df = DataFrame([X_train_std.columns, lr.coef_[0]]).T
#       2 coeff_df
#
# NameError: name 'DataFrame' is not defined

# %%
#max depth (stop at 30 trees as increasing the number of trees decreases the test performance)
max_depths = np.linspace(1, 15, 30, endpoint=True)
train_results = []
test_results = []
for max_depth in max_depths:
   rf = RandomForestClassifier(max_depth=max_depth, n_jobs=-1)
   rf.fit(X_train_rf, y_train_rf)
   train_pred = rf.predict(X_train_rf)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train_rf, train_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   train_results.append(roc_auc)
   y_pred = rf.predict(X_test_rf)
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test_rf, y_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   test_results.append(roc_auc)

from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(max_depths, train_results, 'b', label="Train AUC")
line2, = plt.plot(max_depths, test_results, 'r', label="Test AUC")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('AUC score')
plt.xlabel('Tree depth')
plt.savefig('tree_depth', dpi=300)
#plt.show()
#次元削減後でも結論、木の深さは4がいい

# %%
#finding the best number of N_estimators
#do a parameter search to find the sweet spot
import matplotlib.pyplot as plt
n_estimators = [1, 2, 4, 8, 10,20, 40, 100, 200, 500]
train_results = []
test_results = []
for estimator in n_estimators:
   rf = RandomForestClassifier(n_estimators=estimator, n_jobs=-1)
   rf.fit(X_train, y_train)
    
   train_pred = rf.predict(X_train)

   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_train, train_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   train_results.append(roc_auc)

   y_pred = rf.predict(X_test)
    
   false_positive_rate, true_positive_rate, thresholds = roc_curve(y_test, y_pred)
   roc_auc = auc(false_positive_rate, true_positive_rate)
   test_results.append(roc_auc)

from matplotlib.legend_handler import HandlerLine2D
line1, = plt.plot(n_estimators, train_results, 'b', label="Train AUC")
line2, = plt.plot(n_estimators, test_results, 'r', label="Test AUC")
plt.legend(handler_map={line1: HandlerLine2D(numpoints=2)})
plt.ylabel('AUC score')
plt.xlabel('n_estimators')
plt.savefig('n_estimators', dpi=300)
#plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(criterion='gini', 
                              max_depth=4, 
                              random_state=1)
tree.fit(X_train_rf, y_train_rf)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=4,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=1,
#             splitter='best')

# %%
#決定木clustering
from pydotplus import graph_from_dot_data
from sklearn.tree import export_graphviz
dot_data_rf = export_graphviz(tree, 
                          filled = True,
                          rounded = True,
                          class_names = ['remain', 'leave'],
                          feature_names = ['MonthlyIncome', 'Age', 'TotalWorkingYears', 'DailyRate',
       'MonthlyRate', 'HourlyRate', 'DistanceFromHome', 'OverTime_Yes',
       'OverTime_No', 'YearsAtCompany', 'PercentSalaryHike',
       'EnvironmentSatisfaction', 'NumCompaniesWorked', 'JobInvolvement',
       'YearsInCurrentRole', 'YearsWithCurrManager', 'TrainingTimesLastYear',
       'WorkLifeBalance', 'StockOptionLevel', 'JobLevel',
       'YearsSinceLastPromotion', 'JobSatisfaction',
       'RelationshipSatisfaction', 'BusinessTravel', 'Education',
       'MaritalStatus_Single'],
                          out_file = None)
graph = graph_from_dot_data(dot_data_rf)
graph.write_png('HR_tree.png')
# Out:
# True

# %%
#ランダムフォレスト 
#caluculation < (1e-3second)は早すぎる
#n_jobs: how many concurrent processes/threads should be used for 
#parallelized routines.  
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

forest = RandomForestClassifier(n_estimators = 50,
                                max_depth=4,
                               random_state = 1212)
forest.fit(X_train_rf, y_train_rf)
estimator = forest.estimators_[4]

# %%
from pydotplus import graph_from_dot_data
from sklearn.tree import export_graphviz
from sklearn.ensemble import RandomForestClassifier

dot_data_revised = export_graphviz(estimator, 
                          filled = True,
                          rounded = True,
                          class_names = ['remain', 'leave'],
                          feature_names = ['MonthlyIncome', 'Age', 'TotalWorkingYears',
       'DistanceFromHome', 'MonthlyRate', 'DailyRate', 'HourlyRate',
       'NumCompaniesWorked', 'YearsAtCompany', 'OverTime_Yes', 'OverTime_No',
       'EnvironmentSatisfaction', 'PercentSalaryHike', 'YearsWithCurrManager',
       'JobInvolvement', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'TrainingTimesLastYear', 'JobSatisfaction', 'RelationshipSatisfaction',
       'WorkLifeBalance', 'StockOptionLevel', 'JobLevel', 'BusinessTravel',
       'Education', 'MaritalStatus_Single'],
                          out_file = None)
graph = graph_from_dot_data(dot_data_revised)
graph.write_png('HR_tree_random_forest.png')
# Out:
# True
